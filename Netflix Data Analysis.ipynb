# %%
import pandas as pd
import numpy as np

# %%
data =pd.read_csv("NetflixDataset.csv")

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
data.shape
# Out:
# (7789, 11)

# %%
data.size
# Out:
# 85679

# %%
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 334.7+ KB

# %%
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
data.drop_duplicates(inplace = True)

# %%
data.shape
# Out:
# (7787, 11)

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
#seaborn heatmap
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
#id of house of cards
data[data['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
#title contains House of Cards
data[data['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
data['Date_N'] =pd.to_datetime(data['Release_Date'])

# %%
data['Date_N'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Date_N, dtype: int64

# %%
data['Date_N'].dt.year.value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
#counting the records having different categories
data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
#plotting category feature
sns.countplot(data['Category'])
# Out:
# C:\Users\Ali_Abdullah\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
#showing data where category is equal to 'TV Show' and country is equal to Pakistan
data[(data['Category'] == 'TV Show')&(data['Country']=='Pakistan')].value_counts().to_frame()
# Out:
#                                                                                                                                                                                                                                                                0
# Show_Id Category Title          Director       Cast                                               Country  Release_Date      Rating Duration Type                                               Description                                        Date_N
# s5338   TV Show  Sadqay Tumhare Ehtesham Uddin Mahira Khan, Samiya Mumtaz, Adnan Malik, Rehan ... Pakistan December 15, 2016 TV-PG  1 Season International TV Shows, Romantic TV Shows, TV D... An arranged engagement between a village girl a... 2016-12-15  1

# %%
data.Category.value_counts()
# Out:
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
#showing data where category is equal to 'Movie' and country is equal to Pakistan
data[(data['Category'] == 'Movie')&(data['Country']=='Pakistan')].value_counts().to_frame()
# Out:
#                                                                                                                                                                                                                                                                                       0
# Show_Id Category Title                       Director                Cast                                               Country  Release_Date       Rating Duration Type                                               Description                                        Date_N
# s1264   Movie    Chalay Thay Saath           Umer Adil               Syra Shehroz, Kent S. Leung, Osama Tahir, Mansh... Pakistan May 15, 2018       TV-14  118 min  Comedies, Dramas, International Movies             Beautiful and adventurous doctor Resham meets a... 2018-05-15  1
# ...

# %%
data[(data['Category'] == 'Movie')]['Title'].to_frame()
# Out:
#                                         Title
# 1                                       07:19
# 2                                       23:59
# 3                                           9
# 4                                          21
# 6                                         122
# ...                                       ...
# 7783                                     Zoom
# 7784                                     Zozo
# 7785                                   Zubaan
# 7786                        Zulu Man in Japan
# 7788  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
# [5377 rows x 1 columns]

# %%
data['Type'].value_counts().to_frame()
# Out:
#                                                     Type
# Documentaries                                        334
# Stand-Up Comedy                                      321
# Dramas, International Movies                         320
# Comedies, Dramas, International Movies               243
# Dramas, Independent Movies, International Movies     215
# ...                                                  ...
# Crime TV Shows, Romantic TV Shows, Spanish-Lang...     1
# Crime TV Shows, International TV Shows, Reality TV     1
# International Movies, Romantic Movies, Sci-Fi &...     1
# Stand-Up Comedy & Talk Shows, TV Mysteries, TV ...     1
# International TV Shows, Spanish-Language TV Sho...     1
#
# [492 rows x 1 columns]

# %%
#
data[(data['Category']=='Movie')&(data['Type']=='Stand-Up Comedy')|(data['Country']=='Pakistan')].value_counts().to_frame().head()
# Out:
#                                                                                                                                                                                                                                                                         0
# Show_Id Category Title                                Director                       Cast                                               Country        Release_Date      Rating Duration Type            Description                                        Date_N
# s1010   Movie    Bo Burnham: what.                    Bo Burnham, Christopher Storer Bo Burnham                                         United States  July 1, 2018      TV-MA  60 min   Stand-Up Comedy Left brain and right brain duke it out – and ul... 2018-07-01  1
# ...

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data['Cast'].str.contains('Tom Cruise').count()
# Out:
# 7069

# %%
#dropping null values
New_Data = data.dropna()

# %%
New_Data.isnull().sum()
# Out:
# Show_Id         0
# Category        0
# Title           0
# Director        0
# Cast            0
# Country         0
# Release_Date    0
# Rating          0
# Duration        0
# Type            0
# Description     0
# Date_N          0
# dtype: int64

# %%
#Ratings
New_Data.Rating.nunique()
# Out:
# 14

# %%
#Unique Ratings
New_Data['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
#Category is TV-Show and Rating = 'TV-Y7'
data[(data['Category']=='TV Show')&(data['Rating']=='TV-Y7')].value_counts().to_frame()
# Out:
#                                                                                                                                                                                                                                                                                             0
# Show_Id Category Title                                   Director           Cast                                               Country                    Release_Date      Rating Duration  Type                            Description                                        Date_N
# s2440   TV Show  Glitter Force Doki Doki                 Go Koga            Debi Derryberry, Cassandra Morris, Melissa Fahn... Japan                      November 10, 2017 TV-Y7  2 Seasons Anime Series, Kids' TV          Four girls summon their inner superheroes to de... 2017-11-10  1
# ...

# %%
data[(data['Category']=='TV Show')&(data['Rating']=='TV-Y7')].value_counts().to_frame()
# Out:
#                                                                                                                                                                                                                                                                                             0
# Show_Id Category Title                                   Director           Cast                                               Country                    Release_Date      Rating Duration  Type                            Description                                        Date_N
# s2440   TV Show  Glitter Force Doki Doki                 Go Koga            Debi Derryberry, Cassandra Morris, Melissa Fahn... Japan                      November 10, 2017 TV-Y7  2 Seasons Anime Series, Kids' TV          Four girls summon their inner superheroes to de... 2017-11-10  1
# ...

# %%
New_Data.Duration.unique()
# Out:
# array(['93 min', '78 min', '80 min', '123 min', '1 Season', '95 min',
#        '119 min', '118 min', '143 min', '103 min', '89 min', '91 min',
#        '149 min', '144 min', '124 min', '110 min', '128 min', '117 min',
#        '100 min', '99 min', '102 min', '104 min', '105 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '87 min', '109 min',
#        '101 min', '90 min', '113 min', '114 min', '130 min', '94 min',
#        '140 min', '135 min', '82 min', '70 min', '92 min', '164 min',
#        '83 min', '116 min', '84 min', '86 min', '120 min', '96 min',
#        '126 min', '75 min', '129 min', '77 min', '137 min', '148 min',
#        '121 min', '122 min', '176 min', '85 min', '22 min', '68 min',
#        '111 min', '29 min', '142 min', '168 min', '59 min', '108 min',
#        '44 min', '26 min', '156 min', '98 min', '57 min', '150 min',
#        '133 min', '115 min', '154 min', '127 min', '146 min', '136 min',
# ...

# %%
New_Data.Duration.dtypes
# Out:
# dtype('O')

# %%
New_Data[['minutes','units']] =New_Data.Duration.str.split(' ',expand =True)
# Out:
# C:\Users\Ali_Abdullah\AppData\Local\Temp\ipykernel_11896\1496881818.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   New_Data[['minutes','units']] =New_Data.Duration.str.split(' ',expand =True)
# C:\Users\Ali_Abdullah\AppData\Local\Temp\ipykernel_11896\1496881818.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   New_Data[['minutes','units']] =New_Data.Duration.str.split(' ',expand =True)

# %%
New_Data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description     Date_N minutes units
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23      93   min
# 2  When an army recruit is found dead, his fellow... 2018-12-20      78   min

# %%
New_Data.minutes.max()
# Out:
# '99'

# %%
New_Data.minutes.min()
# Out:
# '1'

# %%
tvshow_data=New_Data[New_Data['Category'] == 'TV Show']

# %%
tvshow_data.Country.value_counts()
# Out:
# United States                                                    27
# United Kingdom                                                   19
# Japan                                                            10
# South Korea                                                      10
# Spain                                                             7
# Taiwan                                                            6
# Turkey                                                            5
# India                                                             5
# Brazil                                                            4
# Canada                                                            3
# Thailand                                                          3
# Nigeria                                                           3
# France                                                            3
# China                                                             2
# ...

# %%
New_Data.Type.count()
# Out:
# 4809

# %%
New_Data.isnull().sum()
# Out:
# Show_Id         0
# Category        0
# Title           0
# Director        0
# Cast            0
# Country         0
# Release_Date    0
# Rating          0
# Duration        0
# Type            0
# Description     0
# Date_N          0
# minutes         0
# units           0
# dtype: int64
